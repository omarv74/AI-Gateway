# %% [markdown]
# # APIM ❤️ FinOps
#
# ## FinOps Framework lab
# ![flow](../../images/finops-framework.gif)
#
# This playground leverages the [FinOps Framework](https://www.finops.org/framework/) and Azure API Management to control AI costs. It uses the [token limit](https://learn.microsoft.com/en-us/azure/api-management/azure-openai-token-limit-policy) policy for each [product](https://learn.microsoft.com/en-us/azure/api-management/api-management-howto-add-products?tabs=azure-portal&pivots=interactive) and integrates [Azure Monitor alerts](https://learn.microsoft.com/en-us/azure/azure-monitor/alerts/alerts-overview) with [Logic Apps](https://learn.microsoft.com/en-us/azure/azure-monitor/alerts/alerts-logic-apps?tabs=send-email) to automatically disable APIM [subscriptions](https://learn.microsoft.com/en-us/azure/api-management/api-management-subscriptions) that exceed cost quotas.
#
# ### Result
# ![result](result.png)
#
# ### Prerequisites
#
# - [Python 3.12 or later version](https://www.python.org/) installed
# - [VS Code](https://code.visualstudio.com/) installed with the [Jupyter notebook extension](https://marketplace.visualstudio.com/items?itemName=ms-toolsai.jupyter) enabled
# - [Python environment](https://code.visualstudio.com/docs/python/environments#_creating-environments) with the [requirements.txt](../../requirements.txt) or run `pip install -r requirements.txt` in your terminal
# - [An Azure Subscription](https://azure.microsoft.com/free/) with [Contributor](https://learn.microsoft.com/en-us/azure/role-based-access-control/built-in-roles/privileged#contributor) + [RBAC Administrator](https://learn.microsoft.com/en-us/azure/role-based-access-control/built-in-roles/privileged#role-based-access-control-administrator) or [Owner](https://learn.microsoft.com/en-us/azure/role-based-access-control/built-in-roles/privileged#owner) roles
# - [Azure CLI](https://learn.microsoft.com/cli/azure/install-azure-cli) installed and [Signed into your Azure subscription](https://learn.microsoft.com/cli/azure/authenticate-azure-cli-interactively)
#
# ▶️ Click `Run All` to execute all steps sequentially, or execute them `Step by Step`...

# %% [markdown]
# <a id='0'></a>
# ### 0️⃣ Initialize notebook variables
#
# - Resources will be suffixed by a unique string based on your subscription id.
# - Adjust the location parameters according your preferences and on the [product availability by Azure region.](https://azure.microsoft.com/explore/global-infrastructure/products-by-region/?cdn=disable&products=cognitive-services,api-management)
# - Adjust the OpenAI model and version according the [availability by region.](https://learn.microsoft.com/azure/ai-services/openai/concepts/models)

# %%
import os, sys, json
sys.path.insert(1, '../../shared')  # add the shared directory to the Python path
import utils

deployment_name = os.path.basename(os.path.dirname(globals()['__vsc_ipynb_file__']))
resource_group_name = f"ENG-GWU-APIM-{deployment_name}" # change the name to match your naming style
resource_group_location = "eastus2" 

apim_sku = 'Basicv2'
apim_products_config = [{"name": "platinum", "displayName": "Platinum Product", "tpm": 2000, "tokenQuota": 1000000, "tokenQuotaPeriod": "Monthly", "costQuota": 5 },
                    {"name": "gold", "displayName": "Gold Product", "tpm": 1000, "tokenQuota": 1000000, "tokenQuotaPeriod": "Monthly", "costQuota": 5}, 
                    {"name": "silver", "displayName": "Silver Product", "tpm": 500, "tokenQuota": 1000000, "tokenQuotaPeriod": "Monthly", "costQuota": 5}]
apim_users_config = [ ]
apim_subscriptions_config = [{"name": "subscription1", "displayName": "Subscription 1", "product": "platinum" },
                    {"name": "subscription2", "displayName": "Subscription 2", "product": "gold" },
                    {"name": "subscription3", "displayName": "Subscription 3", "product": "silver" },
                     {"name": "subscription4", "displayName": "Subscription 4", "product": "silver" } ]

openai_resource_location = "eastus2"

openai_deployments = [ { "name": "gpt-4o-mini", "model": "gpt-4o-mini", "capacity": 200, "version": "2024-07-18", "sku": "GlobalStandard", "inputTokensMeterSku": "gpt-4o-mini-0718-Inp-glbl", "outputTokensMeterSku": "gpt-4o-mini-0718-Outp-glbl" }, 
            { "name": "gpt-4o", "model": "gpt-4o", "capacity": 200, "version": "2024-11-20", "sku": "GlobalStandard", "inputTokensMeterSku": "gpt-4o-0806-Inp-glbl", "outputTokensMeterSku": "gpt-4o-0806-Outp-glbl" },
            { "name": "o1-mini", "model": "o1-mini", "capacity": 200, "version": "2024-09-12", "sku": "GlobalStandard", "inputTokensMeterSku": "o1 mini input glbl", "outputTokensMeterSku": "o1 mini output glbl"} ]

openai_api_version = "2024-10-21"
currency_code = 'USD'

utils.print_ok('Notebook initialized')
# Out:
# ✅ Notebook initialized ⌚ 11:58:57.579055

# %% [markdown]
# <a id='1'></a>
# ### 1️⃣ Verify the Azure CLI and the connected Azure subscription
#
# The following commands ensure that you have the latest version of the Azure CLI and that the Azure CLI is connected to your Azure subscription.

# %%
output = utils.run("az account show", "Retrieved az account", "Failed to get the current az account")

if output.success and output.json_data:
    current_user = output.json_data['user']['name']
    tenant_id = output.json_data['tenantId']
    subscription_id = output.json_data['id']

    utils.print_info(f"Current user: {current_user}")
    utils.print_info(f"Tenant ID: {tenant_id}")
    utils.print_info(f"Subscription ID: {subscription_id}")

output = utils.run("az ad signed-in-user show", "Retrieved az ad signed-in-user", "Failed to get az ad signed-in-user")
if output.success and output.json_data:
    current_user_object_id = output.json_data['id']
# Out:
# ⚙️ Running: az account show
# ✅ Retrieved az account ⌚ 11:59:08.191265 :0s]
# 👉🏽 Current user: admin@MngEnvMCAP986157.onmicrosoft.com
# 👉🏽 Tenant ID: 06e268d3-585c-4ab5-9219-8b48220b8fd6
# 👉🏽 Subscription ID: e1f7b502-6ec4-4a45-be74-59f2587c55ec
# ⚙️ Running: az ad signed-in-user show
# ✅ Retrieved az ad signed-in-user ⌚ 11:59:08.838378 :0s]

# %% [markdown]
# <a id='2'></a>
# ### 2️⃣ Create deployment using 🦾 Bicep
#
# This lab uses [Bicep](https://learn.microsoft.com/azure/azure-resource-manager/bicep/overview?tabs=bicep) to declarative define all the resources that will be deployed in the specified resource group. Change the parameters or the [main.bicep](main.bicep) directly to try different configurations.
#
# ⚠️ Retry this step if you get deployment error: `workspace not active`

# %%
# Create the resource group if doesn't exist
utils.create_resource_group(resource_group_name, resource_group_location)

# Define the Bicep parameters
bicep_parameters = {
    "$schema": "https://schema.management.azure.com/schemas/2019-04-01/deploymentParameters.json#",
    "contentVersion": "1.0.0.0",
    "parameters": {
        "currentUserObjectId": { "value": current_user_object_id },
        "apimSku": { "value": apim_sku },
        "apimUsersConfig": { "value": apim_users_config },
        "apimSubscriptionsConfig": { "value": apim_subscriptions_config },
        "apimProductsConfig": { "value": apim_products_config },
        "openAIResourceLocation": { "value": openai_resource_location },
        "openAIDeployments": { "value": openai_deployments },
        "openAIAPIVersion": { "value": openai_api_version }
    }
}

# Write the parameters to the params.json file
with open('params.json', 'w') as bicep_parameters_file:
    bicep_parameters_file.write(json.dumps(bicep_parameters))

# Run the deployment
output = utils.run(f"az deployment group create --name {deployment_name} --resource-group {resource_group_name} --template-file main.bicep --parameters params.json",
    f"Deployment '{deployment_name}' succeeded", f"Deployment '{deployment_name}' failed")
# Out:
# ⚙️ Running: az group show --name ENG-GWU-APIM-finops-framework
# 👉🏽 Resource group ENG-GWU-APIM-finops-framework does not yet exist. Creating the resource group now...
# ⚙️ Running: az group create --name ENG-GWU-APIM-finops-framework --location eastus2 --tags source=ai-gateway
# ✅ Resource group 'ENG-GWU-APIM-finops-framework' created ⌚ 12:08:36.300713 :1s]
# ⚙️ Running: az deployment group create --name finops-framework --resource-group ENG-GWU-APIM-finops-framework --template-file main.bicep --parameters params.json
# ✅ Deployment 'finops-framework' succeeded ⌚ 12:10:25.282614 :48s]

# %% [markdown]
# <a id='3'></a>
# ### 3️⃣ Get the deployment outputs
#
# Retrieve the required outputs from the Bicep deployment.

# %%
# Obtain all of the outputs from the deployment
output = utils.run(f"az deployment group show --name {deployment_name} -g {resource_group_name}", f"Retrieved deployment: {deployment_name}", f"Failed to retrieve deployment: {deployment_name}")

if output.success and output.json_data:
    apim_resource_gateway_url = utils.get_deployment_output(output, 'apimResourceGatewayURL', 'APIM API Gateway URL')
    pricing_dcr_endpoint = utils.get_deployment_output(output, 'pricingDCREndpoint', 'Pricing DCR Endpoint')
    pricing_dcr_immutable_id = utils.get_deployment_output(output, 'pricingDCRImmutableId', 'Pricing DCR ImmutableId')
    pricing_dcr_stream = utils.get_deployment_output(output, 'pricingDCRStream', 'Pricing DCR Stream')
    subscription_quota_dcr_endpoint = utils.get_deployment_output(output, 'subscriptionQuotaDCREndpoint', 'Subscription Quota DCR Endpoint')
    subscription_quota_dcr_immutable_id = utils.get_deployment_output(output, 'subscriptionQuotaDCRImmutableId', 'Subscription Quota DCR ImmutableId')
    subscription_quota_dcr_stream = utils.get_deployment_output(output, 'subscriptionQuotaDCRStream', 'Subscription Quota DCR Stream')
    
    apim_subscriptions = json.loads(utils.get_deployment_output(output, 'apimSubscriptions').replace("\'", "\""))
    for subscription in apim_subscriptions:
        subscription_name = subscription['name']
        subscription_key = subscription['key']
        utils.print_info(f"Subscription Name: {subscription_name}")
        utils.print_info(f"Subscription Key: ****{subscription_key[-4:]}")
# Out:
# ⚙️ Running: az deployment group show --name finops-framework -g ENG-GWU-APIM-finops-framework
# ✅ Retrieved deployment: finops-framework ⌚ 12:25:27.796140 :0s]
# 👉🏽 APIM API Gateway URL: https://apim-zkkb2uxidyxii.azure-api.net
# 👉🏽 Pricing DCR Endpoint: https://dcr-pricing-zkkb2uxidyxii-4h0s-eastus2.logs.z1.ingest.monitor.azure.com
# 👉🏽 Pricing DCR ImmutableId: dcr-45fcb987667c456f98428cb81367fff0
# 👉🏽 Pricing DCR Stream: Custom-Json-PRICING_CL
# 👉🏽 Subscription Quota DCR Endpoint: https://dcr-quota-zkkb2uxidyxii-cwvx-eastus2.logs.z1.ingest.monitor.azure.com
# 👉🏽 Subscription Quota DCR ImmutableId: dcr-c86d4719732d45dca51c980db65ed698
# 👉🏽 Subscription Quota DCR Stream: Custom-Json-SUBSCRIPTION_QUOTA_CL
# 👉🏽 Subscription Name: subscription1
# 👉🏽 Subscription Key: ****96d8
# 👉🏽 Subscription Name: subscription2
# 👉🏽 Subscription Key: ****5d11
# 👉🏽 Subscription Name: subscription3
# 👉🏽 Subscription Key: ****c2e7
# 👉🏽 Subscription Name: subscription4
# 👉🏽 Subscription Key: ****c363

# %% [markdown]
# <a id='pricing'></a>
# ### 🔍 Display retail pricing info based on the [pricing API](https://learn.microsoft.com/en-us/rest/api/cost-management/retail-prices/azure-retail-prices)

# %%
# %pip install tabulate

import requests
from tabulate import tabulate

def build_pricing_table(json_data, table_data):
    for item in json_data['Items']:
        meter = item['meterName']
        table_data.append([item['armRegionName'], item['armSkuName'], item['retailPrice']*1000])

table_data = []
table_data.append(['Region', 'SKU', 'Retail Price'])
prices = requests.get(f"https://prices.azure.com/api/retail/prices?currencyCode='{currency_code}'&$filter=productName eq 'Azure OpenAI' and unitOfMeasure eq '1K' and armRegionName eq '{openai_resource_location}'")
if prices.status_code == 200:
    prices_json = prices.json()
    build_pricing_table(prices_json, table_data)
print(tabulate(table_data, headers='firstrow', tablefmt='psql'))
# Out:
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
# Note: you may need to restart the kernel to use updated packages.
# +----------+-----------------------------------------+----------------+
# | Region   | SKU                                     |   Retail Price |
# |----------+-----------------------------------------+----------------|
# | eastus2  | gpt4omini-rt-aud1217 Inp glbl           |         10     |
# | eastus2  | gpt-35-turbo4K-Outp-glbl                |          2     |
# | eastus2  | o3 mini 0131 cached input regnl         |          0.605 |
# | eastus2  | gpt-4-turbo-Vision-128K Input-regional  |         10     |
# | eastus2  | gpt4omini-rt-aud1217 Outp regnl         |         22     |
# | eastus2  | gpt4o realtime cached audio inp regn    |         22     |
# | eastus2  | gpt-4o-rt-txt-1217 Inp DZone            |          5.5   |
# | eastus2  | gpt-4o-rt-txt-1217 cchd Inp rgnl        |          2.75  |
# | eastus2  | gpt 4o mini0718 BatchOutp DataZone      |          0.33  |
# | eastus2  | gpt 4o 1120 Batch Inp glbl              |          1.25  |
# | eastus2  | gpt-4o-mini-transcribe-txt-out-glbl     |          5     |
# | eastus2  | o3 mini 0131 Batch Inp Data Zone        |          0.605 |
# | eastus2  | gpt 4o 0513 Batch Inp Data Zone         |          2.75  |
# | eastus2  | gpt 4.1 mini Outp regnl                 |          1.76  |
# | eastus2  | gpt 4.1 Batch Outp glbl                 |          4     |
# | eastus2  | o1-pro Batch Inp glbl                   |         75     |
# | eastus2  | gpt 4o 1120 cached Inp regnl            |          1.375 |
# | eastus2  | gpt 4.1 nano Batch Outp DZone           |          0.22  |
# | eastus2  | o3 mini 0131 output glbl                |          4.4   |
# | eastus2  | gpt 4.1 nano Batch Inp glbl             |          0.05  |
# | eastus2  | gpt-4o-aud-1217-txt Inp glbl            |          2.5   |
# | eastus2  | file-search-tool-calls-rgnl             |       2750     |
# | eastus2  | gpt4omini-aud1217 Inp DZone             |         11     |
# | eastus2  | gpt-4o-transcribe-txt-out-dz            |         11     |
# | eastus2  | o1 mini Batch Inp Data Zone             |          0.605 |
# | eastus2  | gpt 4o 1120 Inp regnl                   |          2.75  |
# | eastus2  | gpt-4o-0806-FT-outp-glbl                |         10     |
# | eastus2  | gpt4omini-rt-aud1217 cchd Inp DZn       |          0.33  |
# | eastus2  | gpt 4.1 Batch Inp Data Zone             |          1.1   |
# | eastus2  | gpt-35-turbo16K-0125 Inp-glbl           |          0.5   |
# | eastus2  | gpt-4o-0806-FT-inp-glbl                 |          2.5   |
# | eastus2  | gpt-4.1-ft input regional               |          2.2   |
# | eastus2  | gpt 4o 0806 Inp Data Zone               |          2.75  |
# | eastus2  | gpt4omini-rt-aud1217 Inp regnl          |         11     |
# | eastus2  | gpt 4o 0806 Batch Inp Data Zone         |          1.375 |
# | eastus2  | gpt-4o-aud-1217 Inp glbl                |         40     |
# | eastus2  | o1 mini cached input regnl              |          0.605 |
# | eastus2  | gpt 4.5 0227 Outp glbl                  |        150     |
# | eastus2  | gpt-4o-transcribe-txt-inp-rgnl          |          2.75  |
# | eastus2  | gpt-4o-mini-transcribe-aud-inp-glbl     |          3     |
# | eastus2  | gpt-35-turbo4K-FT-Trng-glbl tkn         |          8     |
# | eastus2  | o1 preview input glbl                   |         15     |
# | eastus2  | computer-use-batch-outp-datazone        |          6.6   |
# | eastus2  | computer-use-batch-outp-glbl            |          6     |
# | eastus2  | gpt-4o-64k-outp-alpha-0730-Outp-glbl    |         18     |
# | eastus2  | gpt-4o-transcribe-aud-inp-glbl          |          6     |
# | eastus2  | o1 1216 cached Inp regnl                |          8.25  |
# | eastus2  | o1 1216 Outp regnl                      |         66     |
# | eastus2  | gpt 4.5 0227 cached Inp glbl            |         37.5   |
# | eastus2  | o3 0416 Batch Inp glbl                  |          5     |
# | eastus2  | o3 mini 0131 Batch Outp glbl            |          2.2   |
# | eastus2  | gpt-35-turbo16K-FT-Trng-regnl tkn       |          8     |
# | eastus2  | davinci-002-FT-Trng-glbl tkn            |          6     |
# | eastus2  | gpt-4o-aud-1217-txt Outp regnl          |         11     |
# | eastus2  | gpt-4o-aud-1217 Outp glbl               |         80     |
# | eastus2  | gpt-4.1-mini-ft cached input regnl      |          0.11  |
# | eastus2  | gpt-35-turbo-4k-Output-regional         |          2     |
# | eastus2  | gpt-4o-mini-transcribe-aud-inp-dz       |          3.3   |
# | eastus2  | o1 Batch Inp Data Zone                  |          8.25  |
# | eastus2  | babbage-002-base-glbl                   |          0.4   |
# | eastus2  | o3 mini 0131 input glbl                 |          1.1   |
# | eastus2  | o3 mini 0131 cached input Data Zone     |          0.605 |
# | eastus2  | gpt4o realtime cached text inp glbl     |          2.5   |
# | eastus2  | file-search-tool-calls-glbl             |       2500     |
# | eastus2  | gpt-4.1-ft cached input regional        |          0.55  |
# | eastus2  | o1 mini cached input Data Zone          |          0.605 |
# | eastus2  | gpt4omini-rt-txt1217 cchd Inp glbl      |          0.3   |
# | eastus2  | gpt-4o-0806-Inp-regnl                   |          2.75  |
# | eastus2  | gpt 4.1 mini Inp regnl                  |          0.44  |
# | eastus2  | gpt-4.1-mini-ft cached input global     |          0.1   |
# | eastus2  | gpt-4.1-ft input global                 |          2     |
# | eastus2  | gpt-4o-aud-1217 Inp DZone               |         44     |
# | eastus2  | gpt-35-turbo16K-FT-Outp-glbl            |          1.5   |
# | eastus2  | gpt-35-turbo-Instruct-Output-regional   |          2     |
# | eastus2  | o1 1216 Batch Inp glbl                  |          7.5   |
# | eastus2  | o1-pro Outp regnl                       |        660     |
# | eastus2  | gpt-4-8K-Outp-glbl                      |         60     |
# | eastus2  | gpt-35-turbo-16k-Input-regional         |          3     |
# | eastus2  | o1 preview output glbl                  |         60     |
# | eastus2  | text-embedding-3-large-regional         |          0.13  |
# | eastus2  | gpt 4.1 mini Batch Inp DZone            |          0.22  |
# | eastus2  | gpt-35-turbo4K-FT-Inp-glbl              |          0.5   |
# | eastus2  | gpt4omini-rt-aud1217 Inp DZone          |         11     |
# | eastus2  | computer-use-outp-datazone              |         13.2   |
# | eastus2  | o3 mini 0131 Batch Inp glbl             |          0.55  |
# | eastus2  | o1-pro Inp regnl                        |        165     |
# | eastus2  | gpt 4o 0806 Batch Outp Data Zone        |          5.5   |
# | eastus2  | gpt4omini-rt-txt1217 cchd Inp DZn       |          0.33  |
# | eastus2  | gpt 4.1 cached Inp glbl                 |          0.5   |
# | eastus2  | gpt-4o-transcribe-aud-inp-rgnl          |          6.6   |
# | eastus2  | gpt4o realtimePrvwAudOutp DataZone      |        220     |
# | eastus2  | o3 0416 Batch Outp Data Zone            |         22     |
# | eastus2  | gpt 4o 1120 Outp glbl                   |         10     |
# | eastus2  | gpt-4o-aud-1217-txt Outp DZone          |         11     |
# | eastus2  | gpt 4o 1120 cached Inp Data Zone        |          1.375 |
# | eastus2  | o3 0416 Inp glbl                        |         10     |
# | eastus2  | gpt4omini-rt-txt1217 Outp regnl         |          2.64  |
# | eastus2  | gpt-4o-rt-aud-1217 Outp glbl            |         80     |
# | eastus2  | o1 1216 Inp Data Zone                   |         16.5   |
# | eastus2  | gpt 4o 1120 Batch Inp Data Zone         |          1.375 |
# | eastus2  | o1 1216 Outp Data Zone                  |         66     |
# | eastus2  | gpt-image-1-output-img-rgnl             |         44     |
# | eastus2  | gpt-4.1-ft output regional              |          8.8   |
# | eastus2  | gpt4omini-aud1217-txt Outp regnl        |          0.66  |
# | eastus2  | gpt-4.1-mini FT Training regional       |          5.5   |
# | eastus2  | gpt4omini-rt-aud1217 cchd Inp glbl      |          0.3   |
# | eastus2  | gpt-4o-mini-transcribe-txt-out-rgnl     |          5.5   |
# | eastus2  | gpt 4o 0806 cached Inp Data Zone        |          1.375 |
# | eastus2  | gpt-4o-0806-Batch-Outp-glbl             |          5     |
# | eastus2  | babbage-002-base-regional               |          0.4   |
# | eastus2  | gpt 4.5 0227 Inp DZone                  |         82.5   |
# | eastus2  | gpt4o rtime cached txt inp datazone     |          2.75  |
# | eastus2  | computer-use-inpt-glbl                  |          3     |
# | eastus2  | gpt4omini-aud1217 Outp glbl             |         20     |
# | eastus2  | gpt4omini-rt-txt1217 cchd Inp rgnl      |          0.33  |
# | eastus2  | gpt 4.1 mini Batch Outp glbl            |          0.8   |
# | eastus2  | gpt-4-8K-Output-regional                |         60     |
# | eastus2  | gpt 4.1 mini Inp Data Zone              |          0.44  |
# | eastus2  | babbage-002-FT-Outp-regnl               |          0.4   |
# | eastus2  | o1 mini Batch Outp glbl                 |          2.2   |
# | eastus2  | gpt-35-turbo16K-Outp-glbl               |          4     |
# | eastus2  | gpt-4-turbo-Vision-128K Output-regional |         30     |
# | eastus2  | gpt-35-turbo16K-0125 Outp-glbl          |          1.5   |
# | eastus2  | gpt 4.1 nano Inp glbl                   |          0.1   |
# | eastus2  | gpt4omini-rt-aud1217 cchd Inp rgnl      |          0.33  |
# | eastus2  | davinci-002-FT-Inp-regnl                |          2     |
# | eastus2  | gpt-4o-0806-FT-outp-regnl               |         11     |
# | eastus2  | o1 1216 Batch Outp glbl                 |         30     |
# | eastus2  | gpt 4o mini 0718 cached Inp regnl       |          0.083 |
# | eastus2  | gpt-4o-aud-1217 Outp regnl              |         88     |
# | eastus2  | gpt-4o-mini-transcribe-txt-inp-dz       |          1.375 |
# | eastus2  | gpt-4o-0806-Outp-regnl                  |         11     |
# | eastus2  | gpt-4-32K-Input-regional                |         60     |
# | eastus2  | o1 mini output regnl                    |          4.84  |
# | eastus2  | o1 mini output glbl                     |          4.4   |
# | eastus2  | o3 0416 Outp glbl                       |         40     |
# | eastus2  | gpt-4-8K-Input-regional                 |         30     |
# | eastus2  | gpt-4o-0806-FT-Trng-regnl tkn           |         27.5   |
# | eastus2  | gpt 4.1 mini cached Inp DZone           |          0.11  |
# | eastus2  | gpt-4o-mini-transcribe-txt-inp-rgnl     |          1.375 |
# | eastus2  | gpt 4.1 mini Inp glbl                   |          0.4   |
# | eastus2  | gpt 4.1 nano Batch Outp glbl            |          0.2   |
# | eastus2  | gpt-4-turbo-128K Output-regional        |         30     |
# | eastus2  | o1 preview output regnl                 |         66     |
# | eastus2  | gpt-4-32K-Output-regional               |        120     |
# | eastus2  | o1 1216 Inp glbl                        |         15     |
# | eastus2  | gpt 4.1 Batch Outp Data Zone            |          4.4   |
# | eastus2  | computer-use-batch-inpt-glbl            |          1.5   |
# | eastus2  | gpt 4o 0513 Input global                |          5     |
# | eastus2  | gpt 4.1 Inp glbl                        |          2     |
# | eastus2  | gpt 4.1 nano Outp regnl                 |          0.44  |
# | eastus2  | gpt-4o-mini-0718-Outp-glbl              |          0.6   |
# | eastus2  | gpt-4o-transcribe-txt-inp-glbl          |          2.5   |
# | eastus2  | gpt-4o-rt-aud-1217 Inp DZone            |         44     |
# | eastus2  | gpt-4o-rt-aud-1217 Outp regnl           |         88     |
# | eastus2  | o3 mini 0131 output Data Zone           |          4.84  |
# | eastus2  | gpt 4.5 0227 Batch Inp glbl             |         37.5   |
# | eastus2  | gpt-4-turbo-128K Input-regional         |         10     |
# | eastus2  | gpt4o rtime cached audio inp dzone      |         22     |
# | eastus2  | gpt-4.1-mini-ft input regional          |          0.44  |
# | eastus2  | gpt 4o 0513 Output regional             |         15     |
# | eastus2  | gpt4o realtimePrvwTxtInp DataZone       |          5.5   |
# | eastus2  | o1 1216 Inp regnl                       |         16.5   |
# | eastus2  | gpt-4o-mini-transcribe-aud-inp-rgnl     |          3.3   |
# | eastus2  | o3 mini 0131 cached input glbl          |          0.55  |
# | eastus2  | gpt-4-turbo-Vision-128K Outp-glbl       |         30     |
# | eastus2  | gpt-4o-rt-txt-1217 Inp regnl            |          5.5   |
# | eastus2  | gpt 4.1 nano Inp Data Zone              |          0.11  |
# | eastus2  | gpt4omini-rt-txt1217 Outp glbl          |          2.4   |
# | eastus2  | babbage-002-FT-Trng-regnl tkn           |          0.4   |
# | eastus2  | o1-pro Batch Outp glbl                  |        300     |
# | eastus2  | gpt-image-1-output-img-glbl             |         40     |
# | eastus2  | gpt4o realtimePrvw audio inp regn       |        110     |
# | eastus2  | gpt-4o-mini-0718-Batch-Inp-glbl         |          0.075 |
# | eastus2  | gpt-4o-transcribe-txt-out-rgnl          |         11     |
# | eastus2  | gpt-4o-rt-txt-1217 Outp glbl            |         20     |
# | eastus2  | gpt 4.1 mini Batch Outp DZone           |          0.88  |
# | eastus2  | computer-use-batch-inpt-datazone        |          1.65  |
# | eastus2  | gpt-4o-mini-tts-aud-out-rgnl            |         13.2   |
# | eastus2  | davinci-002-FT-Inp-glbl                 |          2     |
# | eastus2  | gpt-4o-mini-0718-Batch-Outp-glbl        |          0.3   |
# | eastus2  | babbage-002-FT-Inp-glbl                 |          0.4   |
# | eastus2  | gpt 4.1 mini Batch Inp glbl             |          0.2   |
# | eastus2  | gpt4omini-aud1217 Outp DZone            |         22     |
# | eastus2  | gpt-35-turbo16K-1106 Outp-glbl          |          2     |
# | eastus2  | gpt4o rtime cached txt inp rgnl         |          2.75  |
# | eastus2  | gpt-image-1-inp-img-rgnl                |         11     |
# | eastus2  | text-embedding-3-small-glbl             |          0.02  |
# | eastus2  | gpt 4.5 0227 Outp regnl                 |        165     |
# | eastus2  | embedding-ada-glbl                      |          0.1   |
# | eastus2  | gpt4o realtime prvw text inp regn       |          5.5   |
# | eastus2  | gpt 4o 0513 Output Data Zone            |         15     |
# | eastus2  | gpt 4o mini 0718 cached Inp Data Zone   |          0.083 |
# | eastus2  | computer-use-outp-glbl                  |         12     |
# | eastus2  | gpt 4.5 0227 Batch Outp DZone           |         82.5   |
# | eastus2  | gpt-35-turbo-16K-1106 Input-regional    |          1     |
# | eastus2  | gpt 4.1 Batch Inp glbl                  |          1     |
# | eastus2  | gpt4omini-aud1217-txt Inp DZone         |          0.165 |
# | eastus2  | babbage-002-FT-Inp-regnl                |          0.4   |
# | eastus2  | gpt-4o-aud-1217-txt Inp DZone           |          2.75  |
# | eastus2  | gpt-35-turbo4K-Inp-glbl                 |          1.5   |
# | eastus2  | gpt4omini-rt-aud1217 Outp DZone         |         22     |
# | eastus2  | o1 mini Batch Inp glbl                  |          0.55  |
# | eastus2  | gpt 4.5 0227 Batch Outp glbl            |         75     |
# | eastus2  | gpt-4o-rt-aud-1217 Inp glbl             |         40     |
# | eastus2  | gpt-image-1-output-img-dzone            |         44     |
# | eastus2  | gpt4omini-rt-aud1217 Outp glbl          |         20     |
# | eastus2  | gpt-4o-transcribe-aud-inp-dz            |          6.6   |
# | eastus2  | gpt-35-turbo-16K-0125 Input-regional    |          0.5   |
# | eastus2  | gpt 4.1 Outp regnl                      |          8.8   |
# | eastus2  | o1-pro Batch Inp Data Zone              |         82.5   |
# | eastus2  | o3 mini 0131 input Data Zone            |          1.21  |
# | eastus2  | o1 1216 cached Inp glbl                 |          7.5   |
# | eastus2  | o1 preview cached input glbl            |          7.5   |
# | eastus2  | o3 mini 0131 input regnl                |          1.21  |
# | eastus2  | o1-pro Outp glbl                        |        600     |
# | eastus2  | o3 0416 Batch Inp Data Zone             |          5.5   |
# | eastus2  | text-embedding-3-large-glbl             |          0.13  |
# | eastus2  | o1 preview cached input Data Zone       |          8.25  |
# | eastus2  | computer-use-inpt-datazone              |          3.3   |
# | eastus2  | o1 preview input Data Zone              |         16.5   |
# | eastus2  | gpt-4o-transcribe-txt-out-glbl          |         10     |
# | eastus2  | gpt-4o-mini-tts-aud-out-glbl            |         12     |
# | eastus2  | gpt-image-1-inp-img-glbl                |         10     |
# | eastus2  | gpt-4o-0806-cached-FT-inp-regnl         |          1.375 |
# | eastus2  | gpt4o realtimePrvwTxtOutp DataZone      |         22     |
# | eastus2  | gpt-4.1-mini-ft output global           |          1.6   |
# | eastus2  | gpt-4-32K-Inp-glbl                      |         60     |
# | eastus2  | o1 preview output Data Zone             |         66     |
# | eastus2  | gpt-4o-0806-Outp-glbl                   |         10     |
# | eastus2  | gpt 4.1 nano Outp Data Zone             |          0.44  |
# | eastus2  | gpt4o realtimePrvw audio outp glbl      |        200     |
# | eastus2  | o1 mini input regnl                     |          1.21  |
# | eastus2  | gpt-4o-mini-transcribe-txt-out-dz       |          5.5   |
# | eastus2  | gpt 4.5 0227 Outp DZone                 |        165     |
# | eastus2  | o1 Batch Outp glbl                      |         30     |
# | eastus2  | gpt4omini-aud1217-txt Outp glbl         |          0.6   |
# | eastus2  | computer-use-inpt-rgnl                  |          3.3   |
# | eastus2  | gpt-35-turbo16K-FT-Trng-glbl tkn        |          8     |
# | eastus2  | gpt4omini-rt-txt1217 Inp DZone          |          0.66  |
# | eastus2  | gpt-4o-64k-outp-alpha-Inp-regnl         |          6.6   |
# | eastus2  | gpt-35-turbo4K-FT-Outp-regnl            |          1.5   |
# | eastus2  | embedding-ada-datazone                  |          0.11  |
# | eastus2  | gpt 4.1 mini cached Inp regnl           |          0.11  |
# | eastus2  | gpt-35-turbo-16K-1106 Output-regional   |          2     |
# | eastus2  | gpt-4o-mini-tts-aud-out-dz              |         13.2   |
# | eastus2  | gpt 4.1 mini Outp glbl                  |          1.6   |
# | eastus2  | o1 mini output Data Zone                |          4.84  |
# | eastus2  | gpt 4.1 Outp glbl                       |          8     |
# | eastus2  | o3 0416 Inp Data Zone                   |         11     |
# | eastus2  | gpt-4o-rt-aud-1217 cchd Inp glbl        |          2.5   |
# | eastus2  | gpt 4o 0806 Outp Data Zone              |         11     |
# | eastus2  | gpt4o realtimePrvw audio inp glbl       |        100     |
# | eastus2  | davinci-002-FT-Outp-regnl               |          2     |
# | eastus2  | o1-pro Batch Outp Data Zone             |        330     |
# | eastus2  | gpt-4-turbo-Vision-128K Inp-glbl        |         10     |
# | eastus2  | o1 Batch Inp glbl                       |          7.5   |
# | eastus2  | o1-pro Outp Data Zone                   |        660     |
# | eastus2  | gpt 4o 1120 Outp regnl                  |         11     |
# | eastus2  | davinci-002-base-regional               |          2     |
# | eastus2  | gpt-4o-64k-outp-alpha-Outp-regnl        |         19.8   |
# | eastus2  | gpt 4o 1120 Batch Outp Data Zone        |          5.5   |
# | eastus2  | gpt-35-turbo-Instruct-Input-regional    |          1.5   |
# | eastus2  | gpt 4.1 mini cached Inp glbl            |          0.1   |
# | eastus2  | gpt-4o-rt-txt-1217 cchd Inp glbl        |          2.5   |
# | eastus2  | o1 mini input Data Zone                 |          1.21  |
# | eastus2  | gpt-4o-aud-1217-txt Inp regnl           |          2.75  |
# | eastus2  | gpt 4.5 0227 Inp regnl                  |         82.5   |
# | eastus2  | gpt-35-turbo4K-FT-Inp-regnl             |          0.5   |
# | eastus2  | o3 0416 cached Inp regnl                |          2.75  |
# | eastus2  | gpt 4.1 nano Outp glbl                  |          0.4   |
# | eastus2  | gpt4omini-aud1217 Inp glbl              |         10     |
# | eastus2  | o3 0416 Inp regnl                       |         11     |
# | eastus2  | o3 mini 0131 Batch Outp Data Zone       |          2.42  |
# | eastus2  | gpt-4-turbo128K Inp-glbl                |         10     |
# | eastus2  | o1 mini cached input glbl               |          0.55  |
# | eastus2  | file-search-tool-calls-datazone         |       2750     |
# | eastus2  | gpt4o realtime prvw text inp glbl       |          5     |
# | eastus2  | gpt 4o 0513 Output global               |         15     |
# | eastus2  | gpt 4o 1120 Inp Data Zone               |          2.75  |
# | eastus2  | o1 Batch Outp Data Zone                 |         33     |
# | eastus2  | gpt-4-8K-Inp-glbl                       |         30     |
# | eastus2  | o3 mini 0131 output regnl               |          4.84  |
# | eastus2  | gpt 4o mini 0718 Outp Data Zone         |          0.66  |
# | eastus2  | o3 0416 Outp regnl                      |         44     |
# | eastus2  | gpt-4o-64k-outp-alpha-0730-Inp-glbl     |          6     |
# | eastus2  | gpt-4o-0806-FT-inp-regnl                |          2.75  |
# | eastus2  | gpt4omini-rt-txt1217 Outp DZone         |          2.64  |
# | eastus2  | gpt-4o-mini-tts-txt-inp-dz              |          0.66  |
# | eastus2  | gpt-4o-0806-FT-Trng-glbl tkn            |         25     |
# | eastus2  | gpt 4.1 nano cached Inp DZone           |          0.028 |
# | eastus2  | gpt4omini-aud1217 Inp regnl             |         11     |
# | eastus2  | gpt-35-turbo16K-Inp-glbl                |          3     |
# | eastus2  | gpt 4.1 nano cached Inp regnl           |          0.028 |
# | eastus2  | text-embedding-3-small-regional         |          0.02  |
# | eastus2  | gpt-35-turbo-4k-Input-regional          |          1.5   |
# | eastus2  | gpt 4.5 0227 Batch Inp DZone            |         41.25  |
# | eastus2  | gpt-4o-mini-tts-txt-inp-glbl            |          0.6   |
# | eastus2  | gpt-4o-mini-tts-txt-inp-rgnl            |          0.66  |
# | eastus2  | gpt-4o-rt-aud-1217 Inp regnl            |         44     |
# | eastus2  | gpt4omini-rt-txt1217 Inp glbl           |          0.6   |
# | eastus2  | gpt-4-32K-Outp-glbl                     |        120     |
# | eastus2  | gpt 4.1 nano Inp regnl                  |          0.11  |
# | eastus2  | gpt-35-turbo-16K-0125 Output-regional   |          1.5   |
# | eastus2  | gpt4o realtimePrvwAudInp DataZone       |        110     |
# | eastus2  | o1 1216 cached Inp Data Zone            |          8.25  |
# | eastus2  | babbage-002-FT-Outp-glbl                |          0.4   |
# | eastus2  | gpt-35-turbo-Instruct-Outp-glbl         |          2     |
# | eastus2  | gpt-35-turbo16K-FT-Inp-glbl             |          0.5   |
# | eastus2  | gpt-4o-rt-txt-1217 Outp DZone           |         22     |
# | eastus2  | gpt-4o-rt-txt-1217 Outp regnl           |         22     |
# | eastus2  | gpt4omini-aud1217 Outp regnl            |         22     |
# | eastus2  | o1 preview cached input regnl           |          8.25  |
# | eastus2  | o1 1216 Outp glbl                       |         60     |
# | eastus2  | gpt-35-turbo4K-FT-Trng-regnl tkn        |          8     |
# | eastus2  | gpt 4.1 Inp Data Zone                   |          2.2   |
# | eastus2  | davinci-002-base-glbl                   |          2     |
# | eastus2  | gpt-4o-0806-Batch-Inp-glbl              |          1.25  |
# | eastus2  | o3 0416 Batch Outp glbl                 |         20     |
# | eastus2  | gpt-4o-rt-txt-1217 cchd Inp DZn         |          2.75  |
# | eastus2  | gpt 4o 0513 Input regional              |          5     |
# | eastus2  | gpt-4o-mini-0718-Outp-regnl             |          0.66  |
# | eastus2  | gpt-4o-mini-0718-Inp-glbl               |          0.15  |
# | eastus2  | gpt-4o-rt-aud-1217 cchd Inp rgnl        |          2.75  |
# | eastus2  | o1-pro Inp Data Zone                    |        165     |
# | eastus2  | gpt-4o-rt-aud-1217 cchd Inp DZn         |          2.75  |
# | eastus2  | o1 1216 Batch Inp Data Zone             |          8.25  |
# | eastus2  | gpt 4.1 cached Inp regnl                |          0.55  |
# | eastus2  | gpt-4.1-mini-ft input global            |          0.4   |
# | eastus2  | gpt-image-1-inp-txt-dzone               |          5.5   |
# | eastus2  | gpt4omini-aud1217-txt Outp DZone        |          0.66  |
# | eastus2  | gpt-image-1-inp-txt-rgnl                |          5.5   |
# | eastus2  | computer-use-outp-rgnl                  |         13.2   |
# | eastus2  | gpt 4.1 cached Inp Data Zone            |          0.55  |
# | eastus2  | gpt-35-turbo4K-FT-Outp-glbl             |          1.5   |
# | eastus2  | o3 0416 Outp Data Zone                  |         44     |
# | eastus2  | gpt-4.1 FT Training regional            |         27.5   |
# | eastus2  | gpt-image-1-inp-img-dzone               |         11     |
# | eastus2  | gpt-4o-0806-Inp-glbl                    |          2.5   |
# | eastus2  | gpt 4o mini 0718 Batch Inp Data Zone    |          0.083 |
# | eastus2  | gpt-35-turbo-Instruct-Inp-glbl          |          1.5   |
# | eastus2  | gpt4omini-rt-txt1217 Inp regnl          |          0.66  |
# | eastus2  | gpt-35-turbo-16k-Output-regional        |          4     |
# | eastus2  | gpt-35-turbo16K-FT-Inp-regnl            |          0.5   |
# | eastus2  | gpt4o realtimePrvw audio outp regn      |        220     |
# | eastus2  | gpt-4o-rt-aud-1217 Outp DZone           |         88     |
# | eastus2  | o3 0416 cached Inp Data Zone            |          2.75  |
# | eastus2  | gpt-4o-mini-transcribe-txt-inp-glbl     |          1.25  |
# | eastus2  | gpt 4o 1120 Inp glbl                    |          2.5   |
# | eastus2  | gpt-4o-aud-1217-txt Outp glbl           |         10     |
# | eastus2  | gpt 4o mini 0718 Inp Data Zone          |          0.165 |
# | eastus2  | gpt 4o 0806 cached Inp glbl             |          1.25  |
# | eastus2  | gpt-image-1-inp-txt-glbl                |          5     |
# | eastus2  | gpt-35-turbo16K-FT-Outp-regnl           |          1.5   |
# | eastus2  | gpt4omini-aud1217-txt Inp glbl          |          0.15  |
# | eastus2  | o1 preview input regnl                  |         16.5   |
# | eastus2  | gpt-35-turbo16K-1106 Inp-glbl           |          1     |
# | eastus2  | gpt 4o 1120 cached Inp glbl             |          1.25  |
# | eastus2  | gpt-4o-aud-1217 Inp regnl               |         44     |
# | eastus2  | gpt-4.1-ft cached input global          |          0.5   |
# | eastus2  | o1 mini input glbl                      |          1.1   |
# | eastus2  | gpt 4.1 Inp regnl                       |          2.2   |
# | eastus2  | gpt 4.1 mini Outp Data Zone             |          1.76  |
# | eastus2  | gpt 4o 1120 Outp Data Zone              |         11     |
# | eastus2  | gpt 4o 0513 Input Data Zone             |          5     |
# | eastus2  | gpt-4.1-mini-ft output regional         |          1.76  |
# | eastus2  | o1-pro Inp glbl                         |        150     |
# | eastus2  | embedding-ada-regional                  |          0.1   |
# | eastus2  | gpt-4.1-ft output global                |          8     |
# | eastus2  | o3 0416 cached Inp glbl                 |          2.5   |
# | eastus2  | o1 mini Batch Outp Data Zone            |          2.42  |
# | eastus2  | gpt 4.5 0227 Inp glbl                   |         75     |
# | eastus2  | gpt-4o-0806-cached-FT-inp-glbl          |          1.25  |
# | eastus2  | gpt-4o-mini-0718-Inp-regnl              |          0.165 |
# | eastus2  | gpt 4.1 Outp Data Zone                  |          8.8   |
# | eastus2  | gpt 4o 1120 Batch Outp glbl             |          5     |
# | eastus2  | gpt-4.1 FT Training global              |         25     |
# | eastus2  | gpt 4o 0513 Batch Outp Data Zone        |          8.25  |
# | eastus2  | gpt4o realtime prvw text outp regn      |         22     |
# | eastus2  | o1 1216 Batch Outp Data Zone            |         33     |
# | eastus2  | gpt-4-turbo128K Outp-glbl               |         30     |
# | eastus2  | gpt-4.1-mini FT Training global         |          5     |
# | eastus2  | gpt 4.1 nano cached Inp glbl            |          0.025 |
# | eastus2  | gpt 4.5 0227 cached Inp DZone           |         41.25  |
# | eastus2  | gpt4o realtime prvw text outp glbl      |         20     |
# | eastus2  | babbage-002-FT-Trng-glbl tkn            |          0.4   |
# | eastus2  | gpt-4o-aud-1217 Outp DZone              |         88     |
# | eastus2  | gpt 4o mini 0718 cached Inp glbl        |          0.075 |
# | eastus2  | davinci-002-FT-Outp-glbl                |          2     |
# | eastus2  | gpt4omini-aud1217-txt Inp regnl         |          0.165 |
# | eastus2  | davinci-002-FT-Trng-regnl tkn           |          6     |
# | eastus2  | gpt 4o 0806 cached Inp regnl            |          1.375 |
# | eastus2  | gpt4o realtime cached audio inp glbl    |         20     |
# | eastus2  | gpt 4.5 0227 cached Inp regnl           |         41.25  |
# | eastus2  | gpt-4o-rt-txt-1217 Inp glbl             |          5     |
# | eastus2  | gpt-4o-transcribe-txt-inp-dz            |          2.75  |
# | eastus2  | gpt 4.1 nano Batch Inp DZone            |          0.055 |
# +----------+-----------------------------------------+----------------+

# %% [markdown]
# <a id='4'></a>
# ### 4️⃣ Load the pricing data into Azure Monitor custom table
#
# 👉 This script uses retail price information. Please adjust it to apply a discount or to use a flat rate with PTUs.
# 👉 We are multiplying by 1000 to get the retail price per 1K tokens.
# 👉 Deploy this script as a [job](https://learn.microsoft.com/en-us/azure/container-apps/jobs?tabs=azure-cli) to run automatically on a predefined schedule.

# %%
# %pip install azure-identity azure-monitor-ingestion azure-core

import requests
from azure.identity import DefaultAzureCredential
from azure.monitor.ingestion import LogsIngestionClient
from azure.core.exceptions import HttpResponseError
from datetime import datetime, timezone

credential = DefaultAzureCredential()
client = LogsIngestionClient(endpoint=pricing_dcr_endpoint, credential=credential, logging_enable=False)

prices = requests.get(f"https://prices.azure.com/api/retail/prices?currencyCode='{currency_code}'&$filter=productName eq 'Azure OpenAI' and unitOfMeasure eq '1K' and armRegionName eq '{openai_resource_location}'")
if prices.status_code == 200:
    prices_json = prices.json()
    if prices_json and 'Items' in prices_json:
        for deployment in openai_deployments:
            input_tokens_price = next((item['retailPrice'] * 1000 for item in prices_json['Items'] if item.get('skuName') == deployment.get("inputTokensMeterSku")), None)
            output_tokens_price = next((item['retailPrice'] * 1000 for item in prices_json['Items'] if item.get('skuName') == deployment.get("outputTokensMeterSku")), None)
            utils.print_info(f"Adding model {deployment.get('name')} with input / output tokens price {input_tokens_price} / {output_tokens_price}")
            body = [{ "TimeGenerated": str(datetime.now(timezone.utc)),
                    "Model": deployment.get("name"),
                    "InputTokensPrice": input_tokens_price,
                    "OutputTokensPrice": output_tokens_price }]
            try:
                client.upload(rule_id=pricing_dcr_immutable_id, stream_name=pricing_dcr_stream, logs=body)
                utils.print_ok(f"Upload succeeded for model {deployment.get('name')}")
            except HttpResponseError as e:
                utils.print_error(f"Upload failed: {e}")
# Out:
# Collecting azure-identity
#   Using cached azure_identity-1.21.0-py3-none-any.whl (189 kB)
# Collecting azure-monitor-ingestion
#   Using cached azure_monitor_ingestion-1.0.4-py3-none-any.whl (46 kB)
# Collecting azure-core
#   Downloading azure_core-1.33.0-py3-none-any.whl (207 kB)
#      |████████████████████████████████| 207 kB 6.4 MB/s eta 0:00:01
# Collecting msal>=1.30.0
#   Using cached msal-1.32.3-py3-none-any.whl (115 kB)
# Collecting msal-extensions>=1.2.0
#   Downloading msal_extensions-1.3.0-py3-none-any.whl (28 kB)
# Collecting cryptography>=2.5
#   Downloading cryptography-44.0.3-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 96.9 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/codespace/.local/lib/python3.8/site-packages (from azure-identity) (4.13.2)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Requirement already satisfied: requests>=2.21.0 in /usr/lib/python3/dist-packages (from azure-core) (2.22.0)
# Requirement already satisfied: six>=1.11.0 in /usr/lib/python3/dist-packages (from azure-core) (1.14.0)
# Collecting PyJWT[crypto]<3,>=1.0.0
#   Downloading PyJWT-2.9.0-py3-none-any.whl (22 kB)
# Collecting cffi>=1.12; platform_python_implementation != "PyPy"
#   Downloading cffi-1.17.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (446 kB)
#      |████████████████████████████████| 446 kB 88.1 MB/s eta 0:00:01
# Collecting pycparser
#   Downloading pycparser-2.22-py3-none-any.whl (117 kB)
#      |████████████████████████████████| 117 kB 122.3 MB/s eta 0:00:01
# Installing collected packages: pycparser, cffi, cryptography, PyJWT, msal, msal-extensions, azure-core, azure-identity, isodate, azure-monitor-ingestion
# Successfully installed PyJWT-2.9.0 azure-core-1.33.0 azure-identity-1.21.0 azure-monitor-ingestion-1.0.4 cffi-1.17.1 cryptography-44.0.3 isodate-0.7.2 msal-1.32.3 msal-extensions-1.3.0 pycparser-2.22
# Note: you may need to restart the kernel to use updated packages.
# 👉🏽 Adding model gpt-4o-mini with input / output tokens price 0.15 / 0.6
# ✅ Upload succeeded for model gpt-4o-mini ⌚ 12:28:47.600970
# 👉🏽 Adding model gpt-4o with input / output tokens price 2.5 / 10.0
# ✅ Upload succeeded for model gpt-4o ⌚ 12:28:47.779882
# 👉🏽 Adding model o1-mini with input / output tokens price 1.1 / 4.4
# ✅ Upload succeeded for model o1-mini ⌚ 12:28:47.870923

# %% [markdown]
# <a id='5'></a>
# ### 5️⃣ Load the Subscription Quota into Azure Monitor custom table

# %%
import requests
from azure.identity import DefaultAzureCredential
from azure.monitor.ingestion import LogsIngestionClient
from azure.core.exceptions import HttpResponseError
from datetime import datetime, timezone

credential = DefaultAzureCredential()
client = LogsIngestionClient(endpoint=subscription_quota_dcr_endpoint, credential=credential, logging_enable=False)

for subscription in apim_subscriptions_config:
    for product in apim_products_config:
        if product.get("name") == subscription.get("product"):
            cost_quota = product.get("costQuota")
            utils.print_info(f"Adding {subscription.get('name')} with cost quota {cost_quota}")
            body = [{ 
                "TimeGenerated": str(datetime.now(timezone.utc)),
                "Subscription": subscription.get('name'),
                "Email": subscription.get("email"),
                "CostQuota": cost_quota
            }]
            try:
                client.upload(rule_id=subscription_quota_dcr_immutable_id, stream_name=subscription_quota_dcr_stream, logs=body)
                utils.print_ok(f"Upload succeeded for {subscription.get('name')}")
            except HttpResponseError as e:
                utils.print_error(f"Upload failed: {e}")
# Out:
# 👉🏽 Adding subscription1 with cost quota 5
# ✅ Upload succeeded for subscription1 ⌚ 12:29:54.835964
# 👉🏽 Adding subscription2 with cost quota 5
# ✅ Upload succeeded for subscription2 ⌚ 12:29:55.044660
# 👉🏽 Adding subscription3 with cost quota 5
# ✅ Upload succeeded for subscription3 ⌚ 12:29:55.284005
# 👉🏽 Adding subscription4 with cost quota 5
# ✅ Upload succeeded for subscription4 ⌚ 12:29:55.392847

# %% [markdown]
# <a id='sdk'></a>
# ### 🧪 Execute multiple runs using the Azure OpenAI Python SDK
#
# 👉 We will send requests with random subscription and models. Adjust the `sleep_time_ms` and the number of `runs` to your test scenario.

# %%
import time, random
from openai import AzureOpenAI

runs = 12
sleep_time_ms = 150

for i in range(runs):
    apim_subscription = random.choice(apim_subscriptions)
    openai_model = random.choice(openai_deployments)
    client = AzureOpenAI(
        azure_endpoint = apim_resource_gateway_url,
        api_key = apim_subscription.get("key"),
        api_version = openai_api_version
    )
    try:
        response = client.chat.completions.create(
            model = str(openai_model.get('name')),
            messages = [
                {"role": "user", "content": "Can you tell me the time, please?"}
            ],
            extra_headers = {"x-user-id": "alex"}
        )
        print(f"▶️ Run {i+1}/{runs}: [{apim_subscription.get('name')} w/ {openai_model.get('name')}] 💬 {response.choices[0].message.content}")
    except Exception as e:
        print(f"❌ Run {i+1}/{runs}: [{apim_subscription.get('name')} w/ {openai_model.get('name')}] Error: {e}")
    time.sleep(sleep_time_ms/1000)
# Out:
# ▶️ Run 1/12: [subscription1 w/ o1-mini] 💬 I'm sorry, but I can't access real-time information. Please check the current time on your device or a reliable time source.
# ▶️ Run 2/12: [subscription3 w/ gpt-4o] 💬 I don't have access to real-time data or a clock, but you can check the time on your device or nearby clock! 😊 Let me know if there's anything else I can help with.
# ▶️ Run 3/12: [subscription4 w/ o1-mini] 💬 I'm sorry, but I can't provide the current time. Please check the time on your device or another reliable source.
# ▶️ Run 4/12: [subscription2 w/ o1-mini] 💬 I'm sorry, but I can't provide real-time information. Please check your device's clock or another reliable source for the current time.
# ▶️ Run 5/12: [subscription3 w/ o1-mini] 💬 I'm sorry, but I can't provide the current time. Please check the time on your device or another reliable source.
# ▶️ Run 6/12: [subscription1 w/ gpt-4o] 💬 I can't provide real-time information, like the current time, as I don’t have access to live data. However, you can easily check the time on your device or clock! 😊
# ▶️ Run 7/12: [subscription3 w/ gpt-4o] 💬 I don't have real-time capabilities or access to a clock, so I can't tell you the current time. However, you can check the time on your device or nearby clock!
# ▶️ Run 8/12: [subscription3 w/ o1-mini] 💬 I'm sorry, but I can't access real-time information. Please check the current time on your device or another reliable source.
# ▶️ Run 9/12: [subscription1 w/ gpt-4o] 💬 Unfortunately, I can't provide real-time information, such as the current time, as I don't have access to live data. You can check the time on your device or clock! 😊
# ▶️ Run 10/12: [subscription4 w/ gpt-4o] 💬 Unfortunately, I can't provide real-time information, like the current time. However, you can easily check the time on your device, computer, phone, or even a clock nearby! If there's anything else you'd like help with, feel free to ask. 😊
# ▶️ Run 11/12: [subscription3 w/ gpt-4o] 💬 I don't have access to real-time information or clocks. Please check the time on your device or nearby clock. 😊
# ▶️ Run 12/12: [subscription1 w/ o1-mini] 💬 I'm sorry, but I don't have the capability to access real-time information. Please check the current time on your device or another reliable source.

# %% [markdown]
# <a id='workbooks'></a>
# ### 🔍 Open the dashboard and workbooks in the Azure Portal
#
# 👉 The Cost Analysis workbook contains information on the total costs and quotas for each subscription.
# 👉 The [Azure OpenAI Insights workbook](https://github.com/dolevshor/Azure-OpenAI-Insights) provides comprehensive details about service and model usage. Credits to [Dolev Shor](https://github.com/dolevshor/Azure-OpenAI-Insights).
# 👉 The [Alerts workbook](https://github.com/microsoft/AzureMonitorCommunity/tree/master/Azure%20Services) provides information about the alerts triggered by Azure Monitor.

# %% [markdown]
# <a id='clean'></a>
# ### 🗑️ Clean up resources
#
# When you're finished with the lab, you should remove all your deployed resources from Azure to avoid extra charges and keep your Azure subscription uncluttered.
# Use the [clean-up-resources notebook](clean-up-resources.ipynb) for that.
